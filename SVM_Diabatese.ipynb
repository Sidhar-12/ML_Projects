# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
Diabatese_data=pd.read_csv('/content/SVM techniques.csv')
Diabatese_data.head()
# Out:
#    Slope Angle  Nail Length  Nail Inclination   FOS  Result
# 0           45            0                 0  1.01       0
# 1           45            0                 0  1.01       0
# 2           45            0                 0  1.01       0
# 3           45            0                 0  1.01       0
# 4           45            0                 0  1.01       0

# %%
Diabatese_data['Result'].value_counts()
# Out:
# Result
# 0    107
# 1     93
# Name: count, dtype: int64

# %%
Diabatese_data.describe()
# Out:
#        Slope Angle  Nail Length  Nail Inclination         FOS      Result
# count   200.000000   200.000000        200.000000  200.000000  200.000000
# mean     43.000000     7.200000         14.000000    1.357120    0.465000
# std      12.113367     4.128586         12.440815    0.421612    0.500025
# min      25.000000     0.000000          0.000000    0.582000    0.000000
# 25%      35.000000     6.000000          0.000000    1.010000    0.000000
# 50%      45.000000     8.000000         12.500000    1.443500    0.000000
# 75%      50.000000    10.000000         25.000000    1.712500    1.000000
# max      60.000000    12.000000         35.000000    2.285000    1.000000

# %%
Diabatese_data.groupby('Result').mean()
# Out:
#         Slope Angle  Nail Length  Nail Inclination       FOS
# Result
# 0         48.738318     5.084112          8.971963  1.026991
# 1         36.397849     9.634409         19.784946  1.736946

# %%
x=Diabatese_data.drop(columns='Result',axis=1)
y=Diabatese_data['Result']
print(x)
print(y)
# Out:
#      Slope Angle  Nail Length  Nail Inclination    FOS
# 0             45            0                 0  1.010
# 1             45            0                 0  1.010
# 2             45            0                 0  1.010
# 3             45            0                 0  1.010
# 4             45            0                 0  1.010
# ..           ...          ...               ...    ...
# 195           25           12                15  1.851
# 196           25           12                20  1.863
# 197           25           12                25  1.813
# 198           25           12                30  1.804
# 199           25           12                35  1.795
#
# [200 rows x 4 columns]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Result, Length: 200, dtype: int64

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)
#print(x)
#print(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
#print(x.shape,x_train.shape,x_test.shape)

# %%
classifier=svm.SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
classifier.score(x_train,y_train)
# Out:
# 0.99375

# %%
classifier.score(x_test,y_test)
# Out:
# 0.975

# %%
input=(1,85,66,29,0,26.6,0.351,31)
input_array=np.asarray(input)
one_input=input_array.reshape(1,-1)
std_input=scaler.fit_transform(one_input)
#print(std_input)
predictions=classifier.predict(std_input)
print(predictions)
# Out:
# [0]
